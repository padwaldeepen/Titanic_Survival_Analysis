# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
titanic_df = pd.read_csv('train.csv')

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.catplot('Sex',data= titanic_df,kind="count")

# %%
sns.factorplot('Pclass',data=titanic_df,hue='Sex',kind="count")

# %%
def male_female_child(passenger):
    age,sex = passenger
    
    if age<16:
        return 'child'
    else:
        return sex

# %%
titanic_df['person'] = titanic_df[['Age','Sex']].apply(male_female_child,axis=1)

# %%
titanic_df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
sns.factorplot('Pclass',data=titanic_df,hue='person',kind="count")

# %%
titanic_df['Age'].hist(bins=70, grid='off')

# %%
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic_df['person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
fig= sns.FacetGrid(titanic_df,hue='person',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest = titanic_df['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
fig= sns.FacetGrid(titanic_df,hue='Pclass',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest = titanic_df['Age'].max()

fig.set(xlim=(0,oldest))

fig.add_legend()

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# person         891 non-null object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
deck = titanic_df['Cabin'].dropna()

# %%
deck.head()
# Out:
# 1      C85
# 3     C123
# 6      E46
# 10      G6
# 11    C103
# Name: Cabin, dtype: object

# %%
levels = []

for level in deck:
    levels.append(level[0])
    
cabin_df = DataFrame(levels)

cabin_df.columns = ['Cabin']


sns.catplot('Cabin',data=cabin_df,palette='summer',kind="count")

# %%
cabin_df = cabin_df[cabin_df.Cabin != 'T']
titanic_df['deck1'] = cabin_df 
sns.catplot('Cabin',data=cabin_df,palette='spring',kind="count")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person deck1
# 0      0         A/5 21171   7.2500   NaN        S    male     C
# 1      0          PC 17599  71.2833   C85        C  female     C
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female     E
# ...

# %%
sns.catplot('Embarked',data=titanic_df,hue='Pclass', kind="count",order=['C','Q','S'])

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person deck1
# 0      0         A/5 21171   7.2500   NaN        S    male     C
# 1      0          PC 17599  71.2833   C85        C  female     C
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female     E
# ...

# %%
titanic_df['Alone'] = titanic_df.SibSp +titanic_df.Parch

# %%
titanic_df['Alone']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       4
# 8       2
# 9       1
# 10      2
# 11      0
# 12      0
# 13      6
# 14      0
# 15      0
# 16      5
# 17      0
# 18      1
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      4
# 25      6
# 26      0
# 27      5
# 28      0
# 29      0
#        ..
# 861     1
# 862     0
# 863    10
# 864     0
# 865     0
# 866     1
# 867     0
# 868     0
# 869     2
# 870     0
# 871     2
# 872     0
# 873     0
# 874     1
# 875     0
# 876     0
# 877     0
# 878     0
# 879     1
# 880     1
# 881     0
# 882     0
# 883     0
# 884     0
# 885     5
# 886     0
# 887     0
# 888     3
# 889     0
# 890     0
# Name: Alone, Length: 891, dtype: int64

# %%
titanic_df['Alone'].loc[titanic_df['Alone'] > 0] = 'No'
titanic_df['Alone'].loc[titanic_df['Alone'] == 0] = 'Yes'
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
sns.catplot('Alone',data=titanic_df,kind="count")

# %%
titanic_df['Surviour'] =  titanic_df.Survived.map({0:'no',1:'yes'})
sns.catplot('Surviour',data=titanic_df,kind="count")

# %%
sns.catplot('Pclass','Survived',hue='person',data=titanic_df,kind='point')

# %%
sns.lmplot('Age','Survived',data=titanic_df)

# %%
sns.lmplot('Age','Survived',hue='Pclass',data=titanic_df)

# %%
sns.lmplot('Age','Survived',hue='Pclass',data=titanic_df)

# %%
sns.lmplot('Age','Survived',hue='Pclass',data=titanic_df,x_bins=range(10,100,20))

# %%
sns.lmplot('Age','Survived',hue='Sex',data=titanic_df,x_bins=range(10,100,20))

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person deck1 Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male     C    No
# 1      0          PC 17599  71.2833   C85        C  female     C    No
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female     E   Yes
# ...

# %%
sns.catplot('deck1','Survived',data=titanic_df, hue='Sex', kind="point",order=(['A','B','C','D','E','F']))

# %%
sns.catplot('deck1','Survived',data=titanic_df, hue='Sex', kind="point")

# %%
sns.lmplot('SibSp','Survived',data=titanic_df, hue='Alone')

# %%
sns.catplot('Parch','Survived',data=titanic_df, hue='person',kind='point')

# %%
"""
References:
https://www.kaggle.com/c/titanic/overview
https://www.udemy.com/course/learning-python-for-data-analysis-and-visualization/learn/lecture/2677478#overview
"""
# Out:
# '\nReferences:\nhttps://www.kaggle.com/c/titanic/overview\nhttps://www.udemy.com/course/learning-python-for-data-analysis-and-visualization/learn/lecture/2677478#overview\n'
